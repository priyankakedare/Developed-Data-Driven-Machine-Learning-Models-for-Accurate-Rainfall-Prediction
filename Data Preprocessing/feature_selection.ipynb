# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/balancedData.csv")
original_df = pd.read_csv("/content/Dataset.csv")
pd.set_option("display.max_columns", None)

# %%
df
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0             50     13.4     22.9       0.6          8.0      10.7
# 1             50      7.4     25.1       0.0          5.6       7.5
# 2             50     12.9     25.7       0.0          5.6      11.0
# 3             50      9.2     28.0       0.0          1.2       8.2
# 4             50     17.5     32.3       1.0          8.0       4.8
# ...          ...      ...      ...       ...          ...       ...
# 183855        32     11.0     17.9       0.6          1.8       2.1
# 183856        35      4.5     18.6       0.0          2.6       8.2
# 183857         5      5.9     13.7       1.5         14.0       4.0
# 183858        19     13.0     18.8       1.5          2.4       4.9
# 183859        35     12.0     21.0       1.5          2.8       5.7
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 0               4.0           44.0         5.0         3.0          20.0
# 1               2.0           44.0         0.0         6.0           4.0
# 2               5.0           46.0         5.0         6.0          19.0
# 3              11.0           24.0        13.0        14.0          11.0
# 4               4.0           41.0        12.0         0.0           7.0
# ...             ...            ...         ...         ...           ...
# 183855         14.0           28.0         9.0        14.0           9.0
# 183856          9.0           37.0         9.0         9.0          11.0
# 183857          4.0           50.0         7.0         6.0          31.0
# 183858          4.0           39.0        13.0        10.0           9.0
# 183859          2.0           54.0         3.0         0.0          13.0
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 0               24.0         71.0         22.0       1007.7       1007.1
# 1               22.0         44.0         25.0       1010.6       1007.8
# 2               26.0         38.0         30.0       1007.6       1008.7
# 3                9.0         45.0         16.0       1017.6       1012.8
# 4               20.0         82.0         33.0       1010.8       1006.0
# ...              ...          ...          ...          ...          ...
# 183855          13.0         71.0         53.0       1017.6       1016.0
# 183856          28.0         73.0         56.0       1004.9       1003.9
# 183857          20.0         68.0         76.0       1018.9       1019.3
# 183858          19.0         99.0         56.0       1016.9       1014.6
# 183859          31.0         88.0         66.0       1013.1       1013.2
#
#         Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  \
# 0            8.0       7.0     16.9     21.8      False         False
# 1            2.0       3.0     17.2     24.3      False         False
# 2            8.0       2.0     21.0     23.2      False         False
# 3            7.0       7.0     18.1     26.5      False         False
# 4            7.0       8.0     17.8     29.7      False         False
# ...          ...       ...      ...      ...        ...           ...
# 183855       6.0       3.0     13.2     16.2      False          True
# 183856       5.0       7.0     11.3     16.7      False          True
# 183857       8.0       7.0     10.7     11.7       True          True
# 183858       8.0       0.0     16.5     20.5       True          True
# 183859       1.0       3.0     14.9     18.7       True          True
#
#         Date_month
# 0               12
# 1               12
# 2               12
# 3               12
# 4               12
# ...            ...
# 183855           5
# 183856           8
# 183857          10
# 183858           6
# 183859           6
#
# [183860 rows x 23 columns]

# %% [markdown]
# # Feature selection by Filter method

# %%
from sklearn import preprocessing
r_scaler = preprocessing.MinMaxScaler()
r_scaler.fit(df)
modified_data = pd.DataFrame(r_scaler.transform(df), index=df.index, columns=df.columns)
modified_data.head()
# Out:
#    Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0       1.0  0.531593  0.495098  0.400000     0.547945  0.737931     0.266667
# 1       1.0  0.366758  0.549020  0.000000     0.383562  0.517241     0.133333
# 2       1.0  0.517857  0.563725  0.000000     0.383562  0.758621     0.333333
# 3       1.0  0.416209  0.620098  0.000000     0.082192  0.565517     0.733333
# 4       1.0  0.644231  0.725490  0.666667     0.547945  0.331034     0.266667
#
#    WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0       0.591667    0.333333    0.200000      0.540541      0.592593
# 1       0.591667    0.000000    0.400000      0.108108      0.543210
# 2       0.625000    0.333333    0.400000      0.513514      0.641975
# 3       0.258333    0.866667    0.933333      0.297297      0.222222
# 4       0.541667    0.800000    0.000000      0.189189      0.493827
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0     0.646341         0.22     0.200301     0.254518  0.888889  0.777778
# 1     0.317073         0.25     0.287651     0.275602  0.222222  0.333333
# 2     0.243902         0.30     0.197289     0.302711  0.888889  0.222222
# 3     0.329268         0.16     0.498494     0.426205  0.777778  0.777778
# 4     0.780488         0.33     0.293675     0.221386  0.777778  0.888889
#
#     Temp9am   Temp3pm  RainToday  RainTomorrow  Date_month
# 0  0.508439  0.509211        0.0           0.0         1.0
# 1  0.514768  0.575000        0.0           0.0         1.0
# 2  0.594937  0.546053        0.0           0.0         1.0
# 3  0.533755  0.632895        0.0           0.0         1.0
# 4  0.527426  0.717105        0.0           0.0         1.0

# %%
modified_data.tail()
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 183855  0.632653  0.465659  0.372549       0.4     0.123288  0.144828
# 183856  0.693878  0.287088  0.389706       0.0     0.178082  0.565517
# 183857  0.081633  0.325549  0.269608       1.0     0.958904  0.275862
# 183858  0.367347  0.520604  0.394608       1.0     0.164384  0.337931
# 183859  0.693878  0.493132  0.448529       1.0     0.191781  0.393103
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 183855     0.933333       0.325000    0.600000    0.933333      0.243243
# 183856     0.600000       0.475000    0.600000    0.600000      0.297297
# 183857     0.266667       0.691667    0.466667    0.400000      0.837838
# 183858     0.266667       0.508333    0.866667    0.666667      0.243243
# 183859     0.133333       0.758333    0.200000    0.000000      0.351351
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 183855      0.320988     0.646341         0.53     0.498494     0.522590
# 183856      0.691358     0.670732         0.56     0.115964     0.158133
# 183857      0.493827     0.609756         0.76     0.537651     0.621988
# 183858      0.469136     0.987805         0.56     0.477410     0.480422
# 183859      0.765432     0.853659         0.66     0.362952     0.438253
#
#         Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday  RainTomorrow  \
# 183855  0.666667  0.333333  0.430380  0.361842        0.0           1.0
# 183856  0.555556  0.777778  0.390295  0.375000        0.0           1.0
# 183857  0.888889  0.777778  0.377637  0.243421        1.0           1.0
# 183858  0.888889  0.000000  0.500000  0.475000        1.0           1.0
# 183859  0.111111  0.333333  0.466245  0.427632        1.0           1.0
#
#         Date_month
# 183855    0.363636
# 183856    0.636364
# 183857    0.818182
# 183858    0.454545
# 183859    0.454545

# %%
from sklearn.feature_selection import SelectKBest, chi2
X = modified_data.loc[:,modified_data.columns!='RainTomorrow']
y = modified_data[['RainTomorrow']]
selector = SelectKBest(chi2, k=7)
selector.fit(X, y)
X_new = selector.transform(X)
print(X.columns[selector.get_support(indices=True)])
# Out:
# Index(['Rainfall', 'Sunshine', 'Humidity9am', 'Humidity3pm', 'Cloud9am',
#        'Cloud3pm', 'RainToday'],
#       dtype='object')
